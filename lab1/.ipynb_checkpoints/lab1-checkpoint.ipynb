# %%
import pandas as pd
import sklearn
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
import numpy as np
import seaborn as sb
import statsmodels.api as sm

# %%
# Loading data
data = pd.read_excel('ЛР1 ПАД.xlsx')
X = data.drop(data.columns[[0, 1]], axis=1)
Y = data['Y']
print(Y)
X
# Out:
# 0     60.1
# 1     58.5
# 2     57.4
# 3     58.5
# 4     58.3
# 5     58.2
# 6     56.5
# 7     59.2
# 8     58.1
# 9     58.8
# 10    56.5
# 11    57.1
# 12    58.3
# 13    59.8
# 14    60.2
# 15    60.0
# 16    60.7
# 17    60.9
# 18    59.1
# 19    60.3
# 20    60.7
# 21    60.6
# 22    65.9
# 23    62.6
# 24    63.9
# 25    59.5
# 26    59.4
# 27    61.0
# 28    59.4
# 29    60.2
# 30    57.5
# 31    68.9
# 32    59.0
# 33    56.9
# 34    57.7
# 35    58.0
# 36    57.2
# 37    49.7
# 38    56.0
# 39    56.0
# 40    54.7
# 41    56.2
# 42    57.0
# 43    55.0
# 44    57.8
# 45    57.8
# 46    57.2
# 47    58.0
# 48    56.3
# 49    55.7
# 50    50.7
# 51    58.9
# Name: Y, dtype: float64
#       х1    х2   х3   х4    х5   х6   x7    x8    x9
# 0    9.2  15.9  7.8  5.3  16.7  169  148  22.7  2094
# 1    7.6  16.4  6.7  4.7  15.5  144  150  27.9  1768
# 2    7.3  18.3  6.3  4.9  19.6  138  133  33.7  1982
# 3    7.9  16.4  6.8  5.0  17.6  197  155  26.6  1621
# 4    7.9  17.0  6.3  4.4  20.1  182  159  30.5  1631
# 5    8.0  16.9  8.2  4.6  15.5  520  197  19.1  1066
# 6    7.2  17.6  8.1  5.2  16.1  143  165  31.2  1183
# 7    8.7  16.0  7.6  4.4  18.9  214  161  22.7  1308
# 8    7.8  17.9  7.2  4.3  15.7  158  163  24.4  1475
# 9    8.0  16.9  6.9  4.7  16.8  185  146  19.8  2081
# 10   7.5  19.4  6.7  4.6  19.3  153  165  28.6  2109
# 11   7.3  19.4  7.4  5.0  20.1  200  175  16.2  1757
# 12   7.6  17.3  7.1  5.3  12.0  180  154  21.3  2111
# 13  13.5  10.5  7.1  3.4  15.8  100  120  60.3  1417
# 14  10.4  12.9  7.0  3.9  18.5  194  225  22.1  1581
# 15  10.1  13.5  7.1  4.6  18.6  143  137  32.1  1938
# 16   9.1  14.6  7.5  5.1  19.1  141  160  33.2  1443
# 17   8.2  15.0  7.1  4.0  14.7  148  121  30.2  1121
# 18   8.6  14.8  7.3  4.8  14.0  188  207  21.2  1511
# 19   8.9  14.5  6.9  4.2  23.6  138  117  35.3  1601
# 20   8.9  13.4  6.7  3.9  21.8  198  206  16.3  1193
# 21  10.7  14.4  8.0  4.0  18.7  129  130  46.3  1344
# 22  21.8   7.5  6.9  1.3  17.6   86   79  41.5   673
# 23  13.7  10.4  7.1  3.4  14.5  128  102  42.5   859
# 24  12.9  10.3  7.0  3.3  16.3  123  107  45.7   925
# 25  13.3  13.0  6.6  2.6  17.8  128  101  42.8   968
# 26  10.0  15.3  8.8  5.0  19.2  175  160  32.4  1565
# 27  10.7  13.5  8.1  4.5  21.7  151  154  39.6  1325
# 28   9.2  15.8  8.0  4.8  18.7  146  140  33.4  1497
# 29  11.2  12.7  7.3  3.7  18.3  158  191  32.4  1059
# 30   9.4  13.7  6.7  3.4  18.4  158  144  26.1  1915
# 31   9.0  14.6  7.3  4.3  22.6  113  132  50.4  2660
# 32  10.3  13.5  7.5  4.0  19.7  115  145  49.3  1534
# 33   9.2  15.8  5.9  3.8  18.9  184  175  25.7  2654
# 34   8.5  15.6  6.7  4.7  17.5  163  169  29.5  2508
# 35   9.0  14.8  7.0  4.7  16.6  171  182  27.9  1987
# 36  11.7  12.0  6.5  3.5  15.2  122  155  55.2  2580
# 37  20.0  13.0  5.9  1.9  28.0   84  101  73.2  2713
# 38   9.9  14.0  7.1  4.4  24.6  161  201  25.3  2222
# 39   9.8  14.0  7.2  4.8  19.8  246  296  24.2  2417
# 40  10.6  14.6  6.3  3.3  18.1  170  215  32.3  2317
# 41  12.2  12.8  6.9  4.0  20.8   99  112  66.5  2784
# 42  15.3   9.8  8.0  4.7  19.5  170  201  29.2  1483
# 43  10.9  13.6  7.3  5.2  26.4  130  125  28.5  3276
# 44   9.8   8.6  7.3  8.9  34.0   85   73  26.4  1148
# 45   9.4  13.1  6.6  4.7  21.5  144  170  31.8  3095
# 46   9.3  13.1  6.6  5.7  17.8  153  171  29.4  2881
# 47  10.1  12.0  7.2  4.9  23.6  175  187  37.9  2017
# 48   9.1  11.2  7.9  6.7  15.4  211  228  22.7  2064
# 49   8.3  10.9  7.2  7.1  14.2  202  187  24.6  3068
# 50   8.9  17.0  7.2  5.7  22.7  145  169  24.6  3588
# 51   8.6  13.6  7.8  6.0  15.4  155  145  26.6  2471

# %% [markdown]
# ### 1. Нормирование исходных данных

# %%
# Graphs of the distribution of X before normalization
X.plot(kind='hist', subplots=True, figsize=(10, 10), title="X before normalization");
X.drop(columns=['x9']).plot(kind='hist', subplots=True, figsize=(10, 10), title="X without x9 before normalization");

# %% [markdown]
# ###### Вывод: необходимо нормирование данных, так как по гистограмме видно, что разные признаки изменяются в разных масштабах

# %% [markdown]
# **Формула Z-нормализации:**
#
# $ X_i^{'} = \frac{X_i - mean(X_i)}{\sigma_x} $

# %%
# Z data normalization
X_preprocessed = X
for col in X.columns:
    X_preprocessed[col] = (X_preprocessed[col] - X_preprocessed[col].mean()) / X_preprocessed[col].std()

# %%
# Graphs of the distribution of X after normalization
X_preprocessed.plot(kind='hist', subplots=True, figsize=(10, 10), title="Z-normalization for X");

# %%
# matrix X with a free member
X_preprocessed.insert(0, 'x0', 1)
X_preprocessed
# Out:
#     x0        х1        х2        х3        х4        х5        х6        x7  \
# 37  3.323380  1.226826
# 38 -0.605183  0.506551
# 39 -0.695400  0.792607
# 40 -0.031071  0.645912
# 41  2.773873  1.330980
# 42 -0.285321 -0.577529
# 43 -0.342732  2.052722
# 44 -0.514965 -1.068959
# 45 -0.072079  1.787203
# 46 -0.268918  1.473275
# 47  0.428218  0.205825
# 48 -0.818424  0.274772
# 49 -0.662594  1.747595
# 50 -0.662594  2.510412
# 51 -0.498562  0.871823

# %% [markdown]
# ### 2. Расчет весов линейной регрессии по аналитической формуле

# %%
# Matrix X transposition
X_transposed = np.transpose(X_preprocessed)
# Covariance matrix
covariance_matr = np.matmul(X_transposed, X_preprocessed)
# Inverse covariance matrix
covariance_matr_inv = np.linalg.inv(covariance_matr)
# Calculating the weight matrix
analytical_weights = np.matmul(np.matmul(covariance_matr_inv, X_transposed), Y)
pd.DataFrame(analytical_weights)
# Out:
#            0
# 0  58.498077
# 1  -2.760975
# 2  -2.183014
# 3   1.014947
# 4  -2.345928
# 5  -0.185930
# 6  -0.347731
# 7  -1.121743
# 8  -0.599550
# 9  -0.623584

# %%
# Multiply the resulting weights and the matrix X
# Calculate the predicted Y
Y_pred_analytical = np.matmul(X_preprocessed.to_numpy(), analytical_weights.to_numpy())
Y_pred_analytical
# Out:
# array([58.11583684, 58.74652277, 56.18912996, 57.68872412, 57.17064132,
#        58.34198181, 59.46748693, 59.95669468, 58.93179798, 58.2074424 ,
#        55.52662386, 56.47586164, 57.35151421, 61.01246047, 59.00483701,
#        59.48467347, 58.9762365 , 62.70900095, 58.75116108, 60.75615453,
#        60.51670434, 60.98880813, 62.00628685, 62.69091322, 63.16542688,
#        61.38122738, 59.66620981, 60.33566237, 59.80872438, 60.43209435,
#        61.73816356, 59.12409234, 60.57126941, 56.31994306, 57.0548198 ,
#        57.94591125, 58.40028046, 51.71410746, 57.56280597, 54.02858937,
#        56.63216732, 57.24630328, 57.4578836 , 56.75789268, 58.07292091,
#        57.34262827, 55.87196455, 58.15246677, 57.18737237, 56.46161529,
#        53.46801533, 58.93194668])

# %% [markdown]
# ### 3. Построение корреляционной матрицы. Расчет числа обусловленности

# %%
# Correlation matrix
df_plot = sb.heatmap(X_preprocessed.corr(), cmap="coolwarm", annot=True)

# %%
# Condition number of a matrix with l2 normalization
np.linalg.cond(X)
# Out:
# 6.328391426899217

# %% [markdown]
# Число обусловленности равно 5311, что говорит о сильной мультиколлинеарности

# %% [markdown]
# ### 4. Анализ регрессионных остатков

# %%
# Y predicted by the analytical method
MSE = mean_squared_error(Y, Y_pred_analytical)
RMSE = MSE ** 0.5
R2 = r2_score(Y, Y_pred_analytical)

print(f'RMSE: {RMSE}')
print(f'Коэффициент детерминации: {R2}')
# Out:
# RMSE: 1.9502921416622299
# Коэффициент детерминации: 0.5816019054675963

# %% [markdown]
# ### 5. Определение весов линейной регрессии градиентным методом

# %%
# Unit vector of weights for the first iteration
weights_i = [1] * len(X_preprocessed.columns)
# Number of rows
n = len(X)
convergence_step = 0.1
for i in range(1, 100):
    Y_pred_i = np.matmul(X_preprocessed, weights_i)
    MSE = mean_squared_error(Y, Y_pred_i)
    delta = Y - Y_pred_i
    ds_dw = -2/n * (np.matmul(delta, X_preprocessed))
    weights_i = weights_i - convergence_step * ds_dw

Y_pred_i = np.matmul(X_preprocessed, weights_i)
MSE = mean_squared_error(Y, Y_pred_i)
RMSE = MSE ** 0.5
R2 = r2_score(Y, Y_pred_i)

print(f'RMSE: {RMSE}')
print(f'Коэффициент детерминации: {R2}')
# Out:
# RMSE: 1.9756470306990306
# Коэффициент детерминации: 0.5706523714548131

# %% [markdown]
# ### 7. Fit-predict модели линейной регрессии c помощью библиотеки sklearn

# %%
# Creating a model using sklearn
lin_reg = LinearRegression().fit(X, Y)
# Y predicted by the sklearn
Y_pred_sklearn = lin_reg.predict(X)
MSE = mean_squared_error(Y, Y_pred_sklearn)
RMSE = MSE ** 0.5
R2 = r2_score(Y, Y_pred_sklearn)

print(f'MSE: {MSE}')
print(f'RMSE: {RMSE}')
print(f'R2: {R2}')
print(f'\nОценочные коэффициенты:')
pd.DataFrame(lin_reg.coef_)
# Out:
# MSE: 3.803639437829443
# RMSE: 1.9502921416622288
# R2: 0.5816019054675967
#
# Оценочные коэффициенты:
#           0
# 0  0.000000
# 1 -2.760975
# 2 -2.183014
# 3  1.014947
# 4 -2.345928
# 5 -0.185930
# 6 -0.347731
# 7 -1.121743
# 8 -0.599550
# 9 -0.623584

# %% [markdown]
# ### 8. «Эконометрический» результат обучения модели линейной регрессии с помощью библиотеки statmodels

# %%
# Creating a model using statmodels
results = sm.OLS(Y, X).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.582
# Model:                            OLS   Adj. R-squared:                  0.492
# Method:                 Least Squares   F-statistic:                     6.487
# Date:                Tue, 03 Oct 2023   Prob (F-statistic):           9.90e-06
# Time:                        01:17:59   Log-Likelihood:                -108.52
# No. Observations:                  52   AIC:                             237.0
# Df Residuals:                      42   BIC:                             256.6
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x0            58.4981      0.301    194.387      0.000      57.891      59.105
# х1            -2.7610      0.720     -3.832      0.000      -4.215      -1.307
# х2            -2.1830      0.548     -3.987      0.000      -3.288      -1.078
# х3             1.0149      0.407      2.494      0.017       0.194       1.836
# х4            -2.3459      0.647     -3.628      0.001      -3.651      -1.041
# х5            -0.1859      0.354     -0.525      0.602      -0.900       0.528
# х6            -0.3477      0.422     -0.825      0.414      -1.199       0.503
# x7            -1.1217      0.439     -2.558      0.014      -2.007      -0.237
# x8            -0.5996      0.498     -1.203      0.236      -1.605       0.406
# x9            -0.6236      0.422     -1.479      0.147      -1.474       0.227
# ==============================================================================
# Omnibus:                       47.046   Durbin-Watson:                   2.520
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              269.372
# Skew:                           2.213   Prob(JB):                     3.21e-59
# Kurtosis:                      13.234   Cond. No.                         6.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
